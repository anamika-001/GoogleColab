# %% [markdown]
# <a href="https://colab.research.google.com/github/anamika-001/GoogleColab/blob/master/Copy_of_Copy_of_Simple_Lineequaiton.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras

# %%
import numpy as np
import pandas as pd
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
x=np.random.randint(0,200,(200,1))
y=np.random.randint(0,200,(200,1))
z=((10*x)+(5*y)+3)
p=np.random.randint(0,200,(200,1))
#df1=pd.DataFrame(x,columns=['x'])
df1['x']=x
df1['y']=y

# %%
df1.shape[1]
# Out:
# 2

# %%
model1 = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1,input_shape=[2]),
])

# %%
model1.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.6),
               metrics='MSE')

# %%
from sklearn.model_selection import train_test_split

X_train,X_val,Y_train,Y_val=train_test_split(df1,z,shuffle=True,test_size=0.33)

# %%
X_train.shape
# Out:
# (134, 2)

# %%
history=model1.fit(X_train,Y_train,epochs=500, validation_split=0.2,verbose=False)

# %%
val = model1.predict(X_val)
print(val[0:5],Y_val[0:5])
# Out:
# [[1478.     ]
#  [ 458.00003]
#  [2438.     ]
#  [1783.     ]
#  [1728.     ]] [[1478]
#  [ 458]
#  [2438]
#  [1783]
#  [1728]]

# %%
print(history.history)
# Out:
# {'loss': [0.0014510980108752847, 0.0014705696376040578, 0.0014197153504937887, 0.0012060877634212375, 0.00129038211889565, 0.0012156523298472166, 0.0011880849488079548, 0.0012012873776257038, 0.0011597047559916973, 0.0010832514381036162, 0.0010680018458515406, 0.0010644968133419752, 0.0010002738563343883, 0.001011461135931313, 0.000954346964135766, 0.0009437923436053097, 0.0009170400444418192, 0.0008988618501462042, 0.0008759615593589842, 0.0008632851531729102, 0.0008453652844764292, 0.0008713915012776852, 0.0008112372015602887, 0.0007884828373789787, 0.0007774772820994258, 0.0008274340652860701, 0.0008249773527495563, 0.0007126742275431752, 0.0007410871330648661, 0.0006814458174631, 0.0006684082909487188, 0.0006803689175285399, 0.0006940559251233935, 0.0006140792393125594, 0.0006645601242780685, 0.000678108655847609, 0.0006014659884385765, 0.0006164130172692239, 0.0005863933474756777, 0.00060557562392205, 0.0005569279892370105, 0.0006094485288485885, 0.0006998182507231832, 0.0006466589402407408, 0.0006202849326655269, 0.0006480710580945015, 0.0004824736970476806, 0.00047214384539984167, 0.00042654291610233486, 0.0004734245885629207, 0.00044334036647342145, 0.00040853311656974256, 0.0004733296809718013, 0.0004218021349515766, 0.0003956952423322946, 0.00039470335468649864, 0.000379846926080063, 0.0003551922272890806, 0.0003472944372333586, 0.0003350496990606189, 0.00033509364584460855, 0.0003545948420651257, 0.0004810422542504966, 0.0003683528630062938, 0.0003565014631021768, 0.0003058812581002712, 0.0003351912018842995, 0.00031723195570521057, 0.000301319727441296, 0.0002731259446591139, 0.00027691706782206893, 0.00024791338364593685, 0.00024411418417003006, 0.0002365062100579962, 0.00023987784516066313, 0.00023679278092458844, 0.00021604016365017742, 0.00021840687259100378, 0.00021388701861724257, 0.00019530054123606533, 0.0001939790672622621, 0.0002115235838573426, 0.0001866441743914038, 0.00017832174489740282, 0.00017346486856695265, 0.0001817967277020216, 0.0001619136892259121, 0.0001618890673853457, 0.0001619282556930557, 0.00015080487355589867, 0.00015842549328226596, 0.00015844778681639582, 0.0001863673678599298, 0.00013484785449691117, 0.00013220291293691844, 0.000151943473611027, 0.00016110550495795906, 0.00014132351498119533, 0.0001198876416310668, 0.00012701262312475592, 0.00013511044380720705, 0.00011807464034063742, 0.00010573593317531049, 0.00010120765364263207, 0.00010936340549960732, 0.00012022350711049512, 0.00011177622218383476, 0.00013109363499097526, 0.0001306448393734172, 0.00011803403322119266, 0.00010499835480004549, 9.961377509171143e-05, 9.899228462018073e-05, 7.795993587933481e-05, 8.051592885749415e-05, 8.031822653720155e-05, 8.420997619396076e-05, 8.265956421382725e-05, 6.812962965341285e-05, 7.04149788361974e-05, 7.210636977106333e-05, 8.209179941331968e-05, 6.730549648636952e-05, 7.079204078763723e-05, 6.416445830836892e-05, 6.590889097424224e-05, 5.607962521025911e-05, 5.3180694521870464e-05, 5.074261571280658e-05, 5.090080958325416e-05, 4.913812881568447e-05, 4.6729161113034934e-05, 4.531327431323007e-05, 4.402290505822748e-05, 4.282256122678518e-05, 4.2126008338527754e-05, 4.070567956659943e-05, 4.2088653572136536e-05, 3.79138182324823e-05, 3.8675345422234386e-05, 3.8994014175841585e-05, 3.767309317481704e-05, 3.587239916669205e-05, 3.5828659747494385e-05, 3.3536794944666326e-05, 3.341804040246643e-05, 3.0875067750457674e-05, 3.358989124535583e-05, 3.888881838065572e-05, 3.3368087315466255e-05, 3.0224289730540477e-05, 2.7358002625987865e-05, 2.5681492843432352e-05, 2.4771865355432965e-05, 2.3596225219080225e-05, 2.3010743461782113e-05, 2.268964635732118e-05, 2.1242800357867964e-05, 2.0596156900865026e-05, 2.0910732928314246e-05, 1.9773582607740536e-05, 1.865225931396708e-05, 1.820496254367754e-05, 1.7581831343704835e-05, 1.9017670638277195e-05, 1.8282027667737566e-05, 1.738105493132025e-05, 1.6444040738861077e-05, 1.6008671082090586e-05, 1.565372440381907e-05, 1.499704649177147e-05, 1.360391797 ...

# %%
X_val[0:5]
# Out:
#        x    y
# 184  110   75
# 60    29   33
# 197  184  119
# 72   116  124
# 193  127   91

# %%
import matplotlib.pyplot as plt
plt.xlabel("Epoch number")
plt.ylabel("Loss Magnitude")
plt.plot(history.history['loss'])

# %%
print("These are the l0 variables: {}".format(model1.get_weights()))
# Out:
# These are the l0 variables: [array([[10.],
#        [ 5.]], dtype=float32), array([3.0000255], dtype=float32)]

# %%
model1.evaluate(X_train,Y_train)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 4.8651e-11 - MSE: 4.8651e-11
# [4.865118030661364e-11, 4.865118030661364e-11]

# %%
 df1.corr()
# Out:
#           x         y
# x  1.000000  0.111278
# y  0.111278  1.000000

# %%
df=pd.DataFrame(columns=['x','y'])
#df1=pd.DataFrame(x,columns=['y'])
df['x']=[2]
df['y']=[3]

# %%
df
# Out:
#    x  y
# 0  2  3

# %%
val = model1.predict(df)
print(val)
# Out:
# [[38.000027]]
